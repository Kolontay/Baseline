# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold  # k-фолдная валидация
import copy
from catboost import CatBoostClassifier, CatBoostRegressor, Pool
from collections import Counter
from sklearn.metrics import accuracy_score

# %%
target= 'target'

X = df.drop(target, axis=1)
y = df['target']
cat_features = list(X.select_dtypes(include=['object']).columns)

# %% [markdown]
# ### Модель Саtboost + Kfold

# %%
class CvModel:
    def __init__(self, clf):
        self.models = []
        self.clf = clf
        self.scores = []
        
    def fit(self, X, y, cv=3):
        self.models = []
        self.scores = []
        
        kf = KFold(n_splits=cv, shuffle=True)
        for train_index, val_index in kf.split(X):
            now_model = copy.deepcopy(self.clf)
            X_train, X_val = X.iloc[train_index], X.iloc[val_index]
            y_train, y_val = y.iloc[train_index], y.iloc[val_index]
           
            train_dataset = Pool(data=X_train, label=y_train, cat_features=cat_features)
            eval_dataset = Pool(data=X_val, label=y_val, cat_features=cat_features)
            
            now_model.fit(train_dataset, 
                          eval_set=eval_dataset,
                          early_stopping_rounds=150,
                          verbose=100)
            
            acc = accuracy_score(now_model.predict(X_val), y_val)
            print(f'Fold {i}/{cv} acc = {acc}')
            
            self.scores.append(acc)
            self.models.append(now_model)
        print('Mean acc = {}'.format(np.mean(self.scores)))
            
    def predict_proba(self, X):
        if len(self.models) == 0:
            raise Exception("There is not fitted model")
            
        res = [model.predict_proba(X) for model in self.models]
        return np.sum(res, axis=0)
    
    def predict(self, X):
        if len(self.models) == 0:
            raise Exception("There is not fitted model")
            
        preds = np.concatenate([model.predict(X).reshape(-1, 1) for model in self.models], axis=1)
#         print(preds.shape)
        res = [Counter(el).most_common()[0][0] for el in preds]
        return res


params_cat = {
    "n_estimators": 1000, #default кол-во деревьев, n_estimators, num_boost_round
    "learning_rate": 0.0276832670537493, #default
    "depth": 8,#default
    "l2_leaf_reg": 6, #default лямбда при L2
    'colsample_bylevel': 0.5782566005857097,
    'auto_class_weights':"SqrtBalanced",
    'boosting_type': 'Plain',
     'bootstrap_type': 'MVS',
    "use_best_model": True,
    "cat_features": cat_features,
    "task_type": 'CPU',# есть ещё GPU
    "loss_function": 'Logloss', #default
    "eval_metric": 'AUC', #для отслеживания остановки
    'random_seed':42,
}

# %%
clf = CatBoostClassifier(**params_cat)
cv_model = CvModel(clf)

# %%
cv_model.fit( X, y, cv=3)
# Out:
# 0:	test: 0.8684020	best: 0.8684020 (0)	total: 73.7ms	remaining: 1m 13s
# 100:	test: 0.9648975	best: 0.9648975 (100)	total: 7.76s	remaining: 1m 9s
# 200:	test: 0.9676774	best: 0.9676774 (200)	total: 16s	remaining: 1m 3s
# 300:	test: 0.9690638	best: 0.9690638 (300)	total: 23.7s	remaining: 55s
# 400:	test: 0.9696346	best: 0.9696346 (400)	total: 31.1s	remaining: 46.5s
# 500:	test: 0.9702333	best: 0.9702492 (499)	total: 38.7s	remaining: 38.6s
# 600:	test: 0.9704638	best: 0.9704638 (600)	total: 46.8s	remaining: 31.1s
# 700:	test: 0.9707238	best: 0.9707366 (695)	total: 55.4s	remaining: 23.6s
# 800:	test: 0.9708770	best: 0.9708856 (793)	total: 1m 4s	remaining: 16s
# 900:	test: 0.9710350	best: 0.9710761 (886)	total: 1m 12s	remaining: 8.02s
# 999:	test: 0.9711681	best: 0.9711789 (993)	total: 1m 22s	remaining: 0us
#
# bestTest = 0.9711789149
# bestIteration = 993
#
# Shrink model to first 994 iterations.
# Fold price_category/3 acc = 0.9143283582089552
# 0:	test: 0.9039454	best: 0.9039454 (0)	total: 70.6ms	remaining: 1m 10s
# 100:	test: 0.9565584	best: 0.9565584 (100)	total: 7.29s	remaining: 1m 4s
# 200:	test: 0.9602702	best: 0.9602702 (200)	total: 15.7s	remaining: 1m 2s
# 300:	test: 0.9622215	best: 0.9622215 (300)	total: 23.4s	remaining: 54.2s
# 400:	test: 0.9635498	best: 0.9635498 (400)	total: 30.8s	remaining: 46s
# 500:	test: 0.9646270	best: 0.9646270 (500)	total: 38.3s	remaining: 38.1s
# 600:	test: 0.9651490	best: 0.9651702 (599)	total: 46s	remaining: 30.6s
# 700:	test: 0.9655121	best: 0.9655659 (697)	total: 53.7s	remaining: 22.9s
# 800:	test: 0.9659930	best: 0.9660091 (798)	total: 1m 1s	remaining: 15.4s
# 900:	test: 0.9664459	best: 0.9664459 (900)	total: 1m 10s	remaining: 7.79s
# 999:	test: 0.9667400	best: 0.9667400 (999)	total: 1m 22s	remaining: 0us
#
# bestTest = 0.9667399524
# bestIteration = 999
#
# Fold price_category/3 acc = 0.9074626865671642
# 0:	test: 0.9096577	best: 0.9096577 (0)	total: 81.2ms	remaining: 1m 21s
# 100:	test: 0.9597549	best: 0.9597593 (99)	total: 8.33s	remaining: 1m 14s
# 200:	test: 0.9643605	best: 0.9643605 (200)	total: 16s	remaining: 1m 3s
# 300:	test: 0.9660043	best: 0.9660043 (300)	total: 24.8s	remaining: 57.5s
# 400:	test: 0.9669470	best: 0.9669498 (397)	total: 32.8s	remaining: 49.1s
# 500:	test: 0.9676719	best: 0.9676941 (499)	total: 41.2s	remaining: 41s
# 600:	test: 0.9680514	best: 0.9680514 (600)	total: 48.6s	remaining: 32.3s
# 700:	test: 0.9685364	best: 0.9685364 (700)	total: 56.6s	remaining: 24.1s
# 800:	test: 0.9688526	best: 0.9688779 (794)	total: 1m 4s	remaining: 16.1s
# 900:	test: 0.9690597	best: 0.9690597 (900)	total: 1m 12s	remaining: 7.98s
# 999:	test: 0.9691059	best: 0.9691249 (995)	total: 1m 20s	remaining: 0us
#
# bestTest = 0.9691249012
# bestIteration = 995
#
# Shrink model to first 996 iterations.
# Fold price_category/3 acc = 0.9125373134328358
# Mean acc = 0.9114427860696518

# %% [markdown]
# ### OPTUNA + Kfold

# %%
# !pip install optuna catboost -q

# %%
import optuna

# %%
def objective(trial, return_models=False):
    cv = 3
    scores, models = [], []
    
    kf = KFold(n_splits=cv, shuffle=True)
    for train_index, val_index in kf.split(X):
            train_data = X.iloc[train_index], y.iloc[train_index]
            valid_data = X.iloc[val_index], y.iloc[val_index]
            
            # Подаем trials для перебора
            model, y_pred = fit_catboost(trial, train_data, valid_data) # Определили выше
            scores.append(accuracy_score(y_pred, valid_data[1]))
            models.append(model)
            break
         

    result = np.mean(scores)
    
    if return_models:
        return result, models
    else:
        return result
    
def fit_catboost(trial, train, val):
    X_train, y_train = train
    X_val, y_val = val
    
    param = {
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.03),
        "depth": trial.suggest_int("depth", 3, 9),
        "l2_leaf_reg": trial.suggest_int("l2_leaf_reg", 2, 50),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.8),
        "auto_class_weights": trial.suggest_categorical("auto_class_weights", ["SqrtBalanced", "Balanced", "None"]),
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "bootstrap_type": trial.suggest_categorical("bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]),
        "eval_metric": "AUC",
    }
    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 20)
        
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1)
        
    clf = CatBoostClassifier(
        **param,
        thread_count=-1,
        random_seed=42,
        cat_features=cat_features,)

    clf.fit(
        X_train,
        y_train,
        eval_set=(X_val, y_val),
        verbose=0,
        plot=False,
        early_stopping_rounds=5,)

    y_pred = clf.predict(X_val)
    return clf, y_pred

study = optuna.create_study(direction="maximize")
study.optimize(objective,
               n_trials=100,
               n_jobs = -1,
               show_progress_bar=True,)

# %%
print("Best trial: score {}, params {}".format(study.best_trial.value, study.best_trial.params))

# %%
# Out:
# [I 2023-11-14 15:56:18,660] A new study created in memory with name: no-name-8d35020d-6075-4311-b693-d8a14b767ece
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2023-11-14 15:56:20,378] Trial 0 finished with value: 0.8405970149253731 and parameters: {'learning_rate': 0.02863958971825184, 'depth': 4, 'l2_leaf_reg': 42, 'colsample_bylevel': 0.6655680433660395, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.8405970149253731.
# [I 2023-11-14 15:56:20,632] Trial 2 finished with value: 0.844776119402985 and parameters: {'learning_rate': 0.01828142341355038, 'depth': 4, 'l2_leaf_reg': 38, 'colsample_bylevel': 0.5828740116968846, 'auto_class_weights': 'Balanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.57156672547144}. Best is trial 2 with value: 0.844776119402985.
# [I 2023-11-14 15:56:21,915] Trial 4 finished with value: 0.8441791044776119 and parameters: {'learning_rate': 0.014177016167583942, 'depth': 3, 'l2_leaf_reg': 8, 'colsample_bylevel': 0.45583225141869094, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.12738680880477082}. Best is trial 2 with value: 0.844776119402985.
# [I 2023-11-14 15:56:22,400] Trial 5 finished with value: 0.8653731343283582 and parameters: {'learning_rate': 0.020260819766740806, 'depth': 3, 'l2_leaf_reg': 31, 'colsample_bylevel': 0.5256639843900677, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.12692479747226093}. Best is trial 5 with value: 0.8653731343283582.
# [I 2023-11-14 15:56:26,075] Trial 1 finished with value: 0.8832835820895523 and parameters: {'learning_rate': 0.019029541582991905, 'depth': 9, 'l2_leaf_reg': 9, 'colsample_bylevel': 0.6127498067746648, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 9.309828535186176}. Best is trial 1 with value: 0.8832835820895523.
# [I 2023-11-14 15:56:27,129] Trial 7 finished with value: 0.868955223880597 and parameters: {'learning_rate': 0.017177459262925122, 'depth': 9, 'l2_leaf_reg': 11, 'colsample_bylevel': 0.7384310673158854, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 1 with value: 0.8832835820895523.
# [I 2023-11-14 15:56:27,984] Trial 9 finished with value: 0.8170149253731344 and parameters: {'learning_rate': 0.017664749441311463, 'depth': 4, 'l2_leaf_reg': 6, 'colsample_bylevel': 0.05523202966708127, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 1 with value: 0.8832835820895523.
# [I 2023-11-14 15:56:29,231] Trial 3 finished with value: 0.8877611940298508 and parameters: {'learning_rate': 0.02694668385435301, 'depth': 8, 'l2_leaf_reg': 37, 'colsample_bylevel': 0.48908530546797174, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:29,480] Trial 6 finished with value: 0.8671641791044776 and parameters: {'learning_rate': 0.02487529175535978, 'depth': 8, 'l2_leaf_reg': 15, 'colsample_bylevel': 0.3530148898342819, 'auto_class_weights': 'Balanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.45803124215997415}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:30,357] Trial 11 finished with value: 0.8516417910447761 and parameters: {'learning_rate': 0.010874294681913454, 'depth': 4, 'l2_leaf_reg': 42, 'colsample_bylevel': 0.09040758945456866, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:30,719] Trial 12 finished with value: 0.8376119402985075 and parameters: {'learning_rate': 0.022586919134397983, 'depth': 3, 'l2_leaf_reg': 26, 'colsample_bylevel': 0.790671810764599, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:32,311] Trial 8 finished with value: 0.8823880597014926 and parameters: {'learning_rate': 0.025397298302813336, 'depth': 4, 'l2_leaf_reg': 23, 'colsample_bylevel': 0.42959222959771637, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.7800524590728908}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:32,940] Trial 10 finished with value: 0.8862686567164179 and parameters: {'learning_rate': 0.021421733156976465, 'depth': 5, 'l2_leaf_reg': 9, 'colsample_bylevel': 0.22288896189769977, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.362250546457929}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:34,707] Trial 15 finished with value: 0.8223880597014925 and parameters: {'learning_rate': 0.027680639045530354, 'depth': 7, 'l2_leaf_reg': 48, 'colsample_bylevel': 0.6155314616322772, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 15.275630903615296}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:36,166] Trial 14 finished with value: 0.8417910447761194 and parameters: {'learning_rate': 0.02875474338226303, 'depth': 7, 'l2_leaf_reg': 50, 'colsample_bylevel': 0.3599732902838352, 'auto_class_weights': 'None', 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 16.139200319494055}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:36,257] Trial 16 finished with value: 0.8116417910447761 and parameters: {'learning_rate': 0.029147987334625154, 'depth': 6, 'l2_leaf_reg': 34, 'colsample_bylevel': 0.2929664215203971, 'auto_class_weights': 'None', 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 18.978869923957255}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:39,459] Trial 17 finished with value: 0.8614925373134328 and parameters: {'learning_rate': 0.0299045173568393, 'depth': 6, 'l2_leaf_reg': 17, 'colsample_bylevel': 0.24421947764450405, 'auto_class_weights': 'None', 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.6377365463231763}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:40,247] Trial 13 finished with value: 0.8820895522388059 and parameters: {'learning_rate': 0.028953367180010348, 'depth': 7, 'l2_leaf_reg': 24, 'colsample_bylevel': 0.30620847502613574, 'auto_class_weights': 'None', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:41,582] Trial 20 finished with value: 0.8582089552238806 and parameters: {'learning_rate': 0.02289909346074414, 'depth': 5, 'l2_leaf_reg': 2, 'colsample_bylevel': 0.184299155017786, 'auto_class_weights': 'Balanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:42,147] Trial 18 finished with value: 0.8734328358208955 and parameters: {'learning_rate': 0.022631684272341142, 'depth': 6, 'l2_leaf_reg': 19, 'colsample_bylevel': 0.24765680636960538, 'auto_class_weights': 'None', 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.8101428544053584}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:42,406] Trial 19 finished with value: 0.8671641791044776 and parameters: {'learning_rate': 0.02258442329554033, 'depth': 6, 'l2_leaf_reg': 20, 'colsample_bylevel': 0.2302694735036091, 'auto_class_weights': 'Balanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:42,774] Trial 21 finished with value: 0.8495522388059702 and parameters: {'learning_rate': 0.022644198905744848, 'depth': 5, 'l2_leaf_reg': 17, 'colsample_bylevel': 0.1713478426592274, 'auto_class_weights': 'Balanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:46,600] Trial 23 finished with value: 0.8653731343283582 and parameters: {'learning_rate': 0.02639162817270118, 'depth': 5, 'l2_leaf_reg': 31, 'colsample_bylevel': 0.4929674577776092, 'auto_class_weights': 'Balanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:48,334] Trial 24 finished with value: 0.8605970149253731 and parameters: {'learning_rate': 0.019786909373705055, 'depth': 9, 'l2_leaf_reg': 13, 'colsample_bylevel': 0.49412573493248635, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 9.481125880891328}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:49,724] Trial 26 finished with value: 0.8602985074626865 and parameters: {'learning_rate': 0.020164489209105345, 'depth': 9, 'l2_leaf_reg': 12, 'colsample_bylevel': 0.5472263628937841, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 9.341255391096741}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:49,989] Trial 25 finished with value: 0.8668656716417911 and parameters: {'learning_rate': 0.019695130909160023, 'depth': 9, 'l2_leaf_reg': 31, 'colsample_bylevel': 0.4998232537758507, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 8.787447973875638}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:51,017] Trial 22 finished with value: 0.8725373134328358 and parameters: {'learning_rate': 0.02634866799033706, 'depth': 8, 'l2_leaf_reg': 19, 'colsample_bylevel': 0.46173437309664855, 'auto_class_weights': 'Balanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.417001754143191}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:54,606] Trial 27 finished with value: 0.8698507462686568 and parameters: {'learning_rate': 0.02689412782127451, 'depth': 8, 'l2_leaf_reg': 3, 'colsample_bylevel': 0.5559155290104614, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.827839542580916}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:55,646] Trial 29 finished with value: 0.8844776119402985 and parameters: {'learning_rate': 0.026907083451892383, 'depth': 8, 'l2_leaf_reg': 4, 'colsample_bylevel': 0.3892269722535967, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.130066361509635}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:56,027] Trial 30 finished with value: 0.8564179104477612 and parameters: {'learning_rate': 0.02431495274766361, 'depth': 8, 'l2_leaf_reg': 2, 'colsample_bylevel': 0.4060119309677265, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 12.576309494219698}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:56,907] Trial 28 finished with value: 0.871044776119403 and parameters: {'learning_rate': 0.026764756185280156, 'depth': 8, 'l2_leaf_reg': 3, 'colsample_bylevel': 0.39059773202932224, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.164914263235864}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:57,834] Trial 32 finished with value: 0.8564179104477612 and parameters: {'learning_rate': 0.027700219788498393, 'depth': 8, 'l2_leaf_reg': 44, 'colsample_bylevel': 0.39161921149676554, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9828203867888003}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:58,085] Trial 31 finished with value: 0.8498507462686568 and parameters: {'learning_rate': 0.01512892614653492, 'depth': 8, 'l2_leaf_reg': 8, 'colsample_bylevel': 0.3819054564330671, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 12.579363125604809}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:56:59,039] Trial 34 finished with value: 0.8617910447761195 and parameters: {'learning_rate': 0.028134403882045793, 'depth': 7, 'l2_leaf_reg': 7, 'colsample_bylevel': 0.6523431490045569, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.614745296388875}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:57:01,459] Trial 36 finished with value: 0.8838805970149254 and parameters: {'learning_rate': 0.02434605264201431, 'depth': 7, 'l2_leaf_reg': 7, 'colsample_bylevel': 0.6201138757737813, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.141116656370395}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:57:01,747] Trial 35 finished with value: 0.8665671641791045 and parameters: {'learning_rate': 0.02447705798252793, 'depth': 7, 'l2_leaf_reg': 8, 'colsample_bylevel': 0.6495042222813683, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.264149625130196}. Best is trial 3 with value: 0.8877611940298508.
# [I 2023-11-14 15:57:01,860] Trial 33 finished with value: 0.8892537313432836 and parameters: {'learning_rate': 0.02769995827090092, 'depth': 7, 'l2_leaf_reg': 44, 'colsample_bylevel': 0.3636184478627931, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9975347089893736}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:03,814] Trial 39 finished with value: 0.8617910447761195 and parameters: {'learning_rate': 0.02141338937733594, 'depth': 7, 'l2_leaf_reg': 5, 'colsample_bylevel': 0.57807935459578, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.14157781205668762}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:04,120] Trial 38 finished with value: 0.8668656716417911 and parameters: {'learning_rate': 0.024206856884015818, 'depth': 7, 'l2_leaf_reg': 6, 'colsample_bylevel': 0.5714833793040435, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.444903788264988}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:05,176] Trial 40 finished with value: 0.8773134328358209 and parameters: {'learning_rate': 0.029910046886612106, 'depth': 5, 'l2_leaf_reg': 39, 'colsample_bylevel': 0.3302887354595343, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9785338090288929}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:09,158] Trial 41 finished with value: 0.8883582089552239 and parameters: {'learning_rate': 0.029744628016019785, 'depth': 5, 'l2_leaf_reg': 38, 'colsample_bylevel': 0.43746607833150203, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9567610797761088}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:10,297] Trial 42 finished with value: 0.8859701492537313 and parameters: {'learning_rate': 0.025648378701267138, 'depth': 5, 'l2_leaf_reg': 38, 'colsample_bylevel': 0.44128714538730224, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9919878073751245}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:11,565] Trial 37 finished with value: 0.8871641791044776 and parameters: {'learning_rate': 0.024271941409419975, 'depth': 9, 'l2_leaf_reg': 11, 'colsample_bylevel': 0.5928706240803514, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.76087246308431}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:12,181] Trial 44 finished with value: 0.8695522388059701 and parameters: {'learning_rate': 0.02772290896952088, 'depth': 5, 'l2_leaf_reg': 36, 'colsample_bylevel': 0.4383139181161593, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.855383965573409}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:12,786] Trial 43 finished with value: 0.8808955223880597 and parameters: {'learning_rate': 0.02568621151127981, 'depth': 9, 'l2_leaf_reg': 45, 'colsample_bylevel': 0.34775813005941564, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.7515305343251961}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:13,436] Trial 45 finished with value: 0.8802985074626866 and parameters: {'learning_rate': 0.025377669824287956, 'depth': 5, 'l2_leaf_reg': 37, 'colsample_bylevel': 0.44240250014698357, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9905519736200141}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:14,659] Trial 49 finished with value: 0.8280597014925373 and parameters: {'learning_rate': 0.028702415061758992, 'depth': 4, 'l2_leaf_reg': 42, 'colsample_bylevel': 0.5361377914049194, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.846504300308953}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:14,752] Trial 48 finished with value: 0.8462686567164179 and parameters: {'learning_rate': 0.028673596936158306, 'depth': 4, 'l2_leaf_reg': 43, 'colsample_bylevel': 0.5371826826089141, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8715837154044256}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:15,144] Trial 46 finished with value: 0.8764179104477612 and parameters: {'learning_rate': 0.027651744629220855, 'depth': 9, 'l2_leaf_reg': 45, 'colsample_bylevel': 0.5232281873144256, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.7894954933404834}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:16,727] Trial 47 finished with value: 0.8656716417910447 and parameters: {'learning_rate': 0.025710545915518752, 'depth': 9, 'l2_leaf_reg': 45, 'colsample_bylevel': 0.5430411222171454, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.7843168871317652}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:18,400] Trial 50 finished with value: 0.8585074626865672 and parameters: {'learning_rate': 0.027515376211818262, 'depth': 6, 'l2_leaf_reg': 40, 'colsample_bylevel': 0.4692910847126603, 'auto_class_weights': 'None', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:20,163] Trial 54 finished with value: 0.846865671641791 and parameters: {'learning_rate': 0.029341897671019593, 'depth': 6, 'l2_leaf_reg': 34, 'colsample_bylevel': 0.45944489907860014, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.984431747526687}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:23,326] Trial 55 finished with value: 0.8776119402985074 and parameters: {'learning_rate': 0.023594365794826686, 'depth': 5, 'l2_leaf_reg': 28, 'colsample_bylevel': 0.4210736517555565, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9023487991312422}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:24,374] Trial 52 finished with value: 0.8758208955223881 and parameters: {'learning_rate': 0.029612904053729492, 'depth': 6, 'l2_leaf_reg': 28, 'colsample_bylevel': 0.31449408512716476, 'auto_class_weights': 'None', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:24,475] Trial 51 finished with value: 0.8680597014925373 and parameters: {'learning_rate': 0.02992809101650453, 'depth': 6, 'l2_leaf_reg': 47, 'colsample_bylevel': 0.4701803931998759, 'auto_class_weights': 'None', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:24,721] Trial 56 finished with value: 0.8555223880597015 and parameters: {'learning_rate': 0.025869671496899345, 'depth': 4, 'l2_leaf_reg': 41, 'colsample_bylevel': 0.3044507066685118, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9087919295172973}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:26,591] Trial 57 finished with value: 0.8576119402985075 and parameters: {'learning_rate': 0.02509065428002279, 'depth': 3, 'l2_leaf_reg': 47, 'colsample_bylevel': 0.4194836198283564, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.911502927985773}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:26,865] Trial 58 finished with value: 0.871044776119403 and parameters: {'learning_rate': 0.025170327557339583, 'depth': 4, 'l2_leaf_reg': 41, 'colsample_bylevel': 0.3588965899563367, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9183250803315739}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:27,851] Trial 53 finished with value: 0.8847761194029851 and parameters: {'learning_rate': 0.029219882744185494, 'depth': 6, 'l2_leaf_reg': 40, 'colsample_bylevel': 0.47252691427121807, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:28,364] Trial 60 finished with value: 0.862089552238806 and parameters: {'learning_rate': 0.02145485547009749, 'depth': 5, 'l2_leaf_reg': 36, 'colsample_bylevel': 0.3702260961685637, 'auto_class_weights': 'Balanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9981802454501172}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:28,858] Trial 59 finished with value: 0.8805970149253731 and parameters: {'learning_rate': 0.028233261232338262, 'depth': 5, 'l2_leaf_reg': 34, 'colsample_bylevel': 0.41765459554688394, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6937425233311372}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:29,491] Trial 62 finished with value: 0.82 and parameters: {'learning_rate': 0.028351903423170798, 'depth': 5, 'l2_leaf_reg': 35, 'colsample_bylevel': 0.5154500407181766, 'auto_class_weights': 'Balanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6564853989613748}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:30,450] Trial 61 finished with value: 0.8632835820895522 and parameters: {'learning_rate': 0.02840785419165595, 'depth': 5, 'l2_leaf_reg': 35, 'colsample_bylevel': 0.275334524456189, 'auto_class_weights': 'Balanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:31,589] Trial 63 finished with value: 0.8695522388059701 and parameters: {'learning_rate': 0.026569674839039513, 'depth': 5, 'l2_leaf_reg': 10, 'colsample_bylevel': 0.26980093752381, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:31,842] Trial 65 finished with value: 0.8486567164179104 and parameters: {'learning_rate': 0.029271221631934366, 'depth': 6, 'l2_leaf_reg': 38, 'colsample_bylevel': 0.4915533540478147, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:36,389] Trial 66 finished with value: 0.8716417910447761 and parameters: {'learning_rate': 0.02714844184722812, 'depth': 6, 'l2_leaf_reg': 39, 'colsample_bylevel': 0.486992785144699, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:38,211] Trial 67 finished with value: 0.8746268656716418 and parameters: {'learning_rate': 0.02701132693686422, 'depth': 6, 'l2_leaf_reg': 50, 'colsample_bylevel': 0.48740059297832883, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:41,401] Trial 68 finished with value: 0.88 and parameters: {'learning_rate': 0.026271544490595974, 'depth': 6, 'l2_leaf_reg': 15, 'colsample_bylevel': 0.4422033274347019, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:42,198] Trial 69 finished with value: 0.8549253731343284 and parameters: {'learning_rate': 0.029248101068932, 'depth': 8, 'l2_leaf_reg': 15, 'colsample_bylevel': 0.45088357559552567, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:44,023] Trial 64 finished with value: 0.888955223880597 and parameters: {'learning_rate': 0.02898880091574831, 'depth': 6, 'l2_leaf_reg': 10, 'colsample_bylevel': 0.6012815433620056, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:46,618] Trial 71 finished with value: 0.862089552238806 and parameters: {'learning_rate': 0.028994817870552126, 'depth': 7, 'l2_leaf_reg': 22, 'colsample_bylevel': 0.6066742531532294, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.500031633081253}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:46,932] Trial 70 finished with value: 0.8814925373134328 and parameters: {'learning_rate': 0.025981303409184555, 'depth': 7, 'l2_leaf_reg': 23, 'colsample_bylevel': 0.44613582108513133, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:49,543] Trial 73 finished with value: 0.8635820895522388 and parameters: {'learning_rate': 0.025846951218582725, 'depth': 7, 'l2_leaf_reg': 13, 'colsample_bylevel': 0.5981947029928683, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.147105493987957}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:50,366] Trial 74 finished with value: 0.8561194029850746 and parameters: {'learning_rate': 0.028116038214111367, 'depth': 7, 'l2_leaf_reg': 32, 'colsample_bylevel': 0.5109969651546633, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:50,671] Trial 72 finished with value: 0.8808955223880597 and parameters: {'learning_rate': 0.026198022630081134, 'depth': 7, 'l2_leaf_reg': 22, 'colsample_bylevel': 0.5945432880095567, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.5443665552546895}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:53,322] Trial 75 finished with value: 0.8650746268656716 and parameters: {'learning_rate': 0.027834315897366645, 'depth': 6, 'l2_leaf_reg': 12, 'colsample_bylevel': 0.5674661278097914, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:58,621] Trial 77 finished with value: 0.8758208955223881 and parameters: {'learning_rate': 0.027271279977633543, 'depth': 6, 'l2_leaf_reg': 10, 'colsample_bylevel': 0.561935494315053, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:58,621] Trial 78 finished with value: 0.8877611940298508 and parameters: {'learning_rate': 0.027533805929068077, 'depth': 6, 'l2_leaf_reg': 10, 'colsample_bylevel': 0.5682651085861872, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:58,636] Trial 76 finished with value: 0.8850746268656716 and parameters: {'learning_rate': 0.02801289903855579, 'depth': 6, 'l2_leaf_reg': 32, 'colsample_bylevel': 0.5603397740087939, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:57:59,919] Trial 79 finished with value: 0.8877611940298508 and parameters: {'learning_rate': 0.027345839449855233, 'depth': 8, 'l2_leaf_reg': 10, 'colsample_bylevel': 0.4138454244311061, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:58:02,096] Trial 81 finished with value: 0.8540298507462687 and parameters: {'learning_rate': 0.026843588315620955, 'depth': 8, 'l2_leaf_reg': 10, 'colsample_bylevel': 0.6862510047654665, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.759338916708181}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:58:02,382] Trial 80 finished with value: 0.8579104477611941 and parameters: {'learning_rate': 0.026569797245919034, 'depth': 8, 'l2_leaf_reg': 10, 'colsample_bylevel': 0.5147656853153165, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.547869817776251}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:58:05,515] Trial 82 finished with value: 0.8841791044776119 and parameters: {'learning_rate': 0.026764566028046367, 'depth': 8, 'l2_leaf_reg': 10, 'colsample_bylevel': 0.62555973314603, 'auto_class_weights': 'None', 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.1239624411279241}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:58:05,777] Trial 85 finished with value: 0.8767164179104477 and parameters: {'learning_rate': 0.02731966659884704, 'depth': 9, 'l2_leaf_reg': 8, 'colsample_bylevel': 0.39485723025040664, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:58:07,439] Trial 87 finished with value: 0.8656716417910447 and parameters: {'learning_rate': 0.028560687530352583, 'depth': 5, 'l2_leaf_reg': 14, 'colsample_bylevel': 0.4072649747741993, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:58:08,256] Trial 86 finished with value: 0.8761194029850746 and parameters: {'learning_rate': 0.02735355259617095, 'depth': 9, 'l2_leaf_reg': 14, 'colsample_bylevel': 0.39182370110414433, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:58:09,829] Trial 84 finished with value: 0.8853731343283582 and parameters: {'learning_rate': 0.028619336331331464, 'depth': 9, 'l2_leaf_reg': 13, 'colsample_bylevel': 0.405491896252559, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:58:10,089] Trial 88 finished with value: 0.8608955223880597 and parameters: {'learning_rate': 0.024730814788253213, 'depth': 9, 'l2_leaf_reg': 5, 'colsample_bylevel': 0.34649171761948655, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8313030878446159}. Best is trial 33 with value: 0.8892537313432836.
# [I 2023-11-14 15:58:11,447] Trial 83 finished with value: 0.8928358208955224 and parameters: {'learning_rate': 0.026744791999203234, 'depth': 8, 'l2_leaf_reg': 9, 'colsample_bylevel': 0.6292250396753991, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 83 with value: 0.8928358208955224.
# [I 2023-11-14 15:58:11,691] Trial 89 finished with value: 0.868955223880597 and parameters: {'learning_rate': 0.02480330593175217, 'depth': 5, 'l2_leaf_reg': 17, 'colsample_bylevel': 0.5310730046968597, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8476959568987695}. Best is trial 83 with value: 0.8928358208955224.
# [I 2023-11-14 15:58:14,017] Trial 90 finished with value: 0.8961194029850746 and parameters: {'learning_rate': 0.029716197538175747, 'depth': 5, 'l2_leaf_reg': 5, 'colsample_bylevel': 0.42836166699087497, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8506648447877418}. Best is trial 90 with value: 0.8961194029850746.
# [I 2023-11-14 15:58:17,231] Trial 94 finished with value: 0.8626865671641791 and parameters: {'learning_rate': 0.029836470650063052, 'depth': 8, 'l2_leaf_reg': 6, 'colsample_bylevel': 0.589851819218691, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 90 with value: 0.8961194029850746.
# [I 2023-11-14 15:58:19,177] Trial 93 finished with value: 0.8898507462686567 and parameters: {'learning_rate': 0.027839530404761118, 'depth': 8, 'l2_leaf_reg': 7, 'colsample_bylevel': 0.5845064714699258, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 90 with value: 0.8961194029850746.
# [I 2023-11-14 15:58:20,709] Trial 95 finished with value: 0.8773134328358209 and parameters: {'learning_rate': 0.02782980529968912, 'depth': 8, 'l2_leaf_reg': 9, 'colsample_bylevel': 0.6310956787742105, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 90 with value: 0.8961194029850746.
# [I 2023-11-14 15:58:22,894] Trial 91 finished with value: 0.8988059701492538 and parameters: {'learning_rate': 0.025347423580492547, 'depth': 8, 'l2_leaf_reg': 17, 'colsample_bylevel': 0.4331681710993097, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9278831650857176}. Best is trial 91 with value: 0.8988059701492538.
# [I 2023-11-14 15:58:24,063] Trial 96 finished with value: 0.8740298507462687 and parameters: {'learning_rate': 0.028931039270206616, 'depth': 8, 'l2_leaf_reg': 7, 'colsample_bylevel': 0.6308001178177007, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 91 with value: 0.8988059701492538.
# [I 2023-11-14 15:58:30,843] Trial 98 finished with value: 0.8850746268656716 and parameters: {'learning_rate': 0.028906161404905806, 'depth': 8, 'l2_leaf_reg': 4, 'colsample_bylevel': 0.5807019022365938, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 91 with value: 0.8988059701492538.
# [I 2023-11-14 15:58:32,647] Trial 99 finished with value: 0.8883582089552239 and parameters: {'learning_rate': 0.028170110494194003, 'depth': 8, 'l2_leaf_reg': 3, 'colsample_bylevel': 0.43173400319367794, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.924674603152726}. Best is trial 91 with value: 0.8988059701492538.
# [I 2023-11-14 15:58:33,215] Trial 92 finished with value: 0.9008955223880597 and parameters: {'learning_rate': 0.0276832670537493, 'depth': 8, 'l2_leaf_reg': 6, 'colsample_bylevel': 0.5782566005857097, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 92 with value: 0.9008955223880597.
# [I 2023-11-14 15:58:36,438] Trial 97 finished with value: 0.8970149253731343 and parameters: {'learning_rate': 0.028883129162876692, 'depth': 8, 'l2_leaf_reg': 4, 'colsample_bylevel': 0.5765814494806986, 'auto_class_weights': 'SqrtBalanced', 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 92 with value: 0.9008955223880597.

# %% [markdown]
# ### Optuna (без фолдов)

# %%
def objective(trial, return_models=False):

    train_data = X_train, y_train
    valid_data = X_valid, y_valid
            
    # Подаем trials для перебора
    model, y_pred = fit_catboost(trial, train_data, valid_data) # Определили выше
    result = roc_auc_score(valid_data[1],y_pred)
    
    
    if return_models:
        return result, model
    else:
        return result

def fit_catboost(trial, train, val):
    X_train, y_train = train
    X_val, y_val = val
    
    param = {
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "depth": trial.suggest_int("depth", 3, 9), #default = 6
        "l2_leaf_reg": trial.suggest_int("l2_leaf_reg", 2, 50), #default = 3
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.8), #default = 1
        "auto_class_weights": trial.suggest_categorical("auto_class_weights", ["SqrtBalanced", "Balanced", "None"]),#default = None
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),#default = Ordered
        "bootstrap_type": trial.suggest_categorical("bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]), #default = Bayesian
        "eval_metric": "AUC",
    }
    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 20)#default = 1
        
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1)#default = 1
        
    clf = CatBoostClassifier(
        **param,
        thread_count=-1,
        random_seed=42,
        cat_features=cat_features,)

    clf.fit(
        X_train,
        y_train,
        eval_set=(X_val, y_val),
        verbose=200,
        plot=False,
        early_stopping_rounds=5,)

    y_pred = clf.predict_proba(X_val)[:,1]
    return clf, y_pred

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective,
               n_trials=100,
               n_jobs = -1,
               show_progress_bar=True,)
